# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
gb = pd.read_csv("canada_per_capita_income.csv")
gb
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
cd = gb.drop("year",axis= "columns")
plt.scatter(cd, mf)
plt.xlabel("capita income")
plt.ylabel("year")
# Out:
# Text(0, 0.5, 'year')

# %%
mf = gb.year

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit(cd,mf)
# Out:
# LinearRegression()

# %%
reg.intercept_
# Out:
# 1972.6536140098344

# %%
reg.coef_
# Out:
# array([0.00107538])

# %%
cd
# Out:
#     per capita income (US$)
# 0               3399.299037
# 1               3768.297935
# 2               4251.175484
# 3               4804.463248
# 4               5576.514583
# 5               5998.144346
# 6               7062.131392
# 7               7100.126170
# 8               7247.967035
# 9               7602.912681
# 10              8355.968120
# 11              9434.390652
# 12              9619.438377
# 13             10416.536590
# 14             10790.328720
# 15             11018.955850
# 16             11482.891530
# 17             12974.806620
# 18             15080.283450
# 19             16426.725480
# 20             16838.673200
# 21             17266.097690
# 22             16412.083090
# 23             15875.586730
# 24             15755.820270
# 25             16369.317250
# 26             16699.826680
# 27             17310.757750
# 28             16622.671870
# 29             17581.024140
# 30             18987.382410
# 31             18601.397240
# ...

# %%
reg.predict([[41288.69409442]])
# Out:
# array([2017.05475678])

# %%
reg.score(cd,mf)
# Out:
# 0.8909169179570324
